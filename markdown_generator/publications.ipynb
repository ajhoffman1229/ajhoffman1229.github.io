# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat publications.tsv
# Out:
# pub_date	title	venue	excerpt	citation	url_slug	paper_url
# 2009-10-01	Paper Title Number 1	Journal 1	This paper is about the number 1. The number 2 is left for future work.	Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).	paper-title-number-1	http://academicpages.github.io/files/paper1.pdf
# 2010-10-01	Paper Title Number 2	Journal 1	This paper is about the number 2. The number 3 is left for future work.	Your Name, You. (2010). "Paper Title Number 2." <i>Journal 1</i>. 1(2).	paper-title-number-2	http://academicpages.github.io/files/paper2.pdf
# 2015-10-01	Paper Title Number 3	Journal 1	This paper is about the number 3. The number 4 is left for future work.	Your Name, You. (2015). "Paper Title Number 3." <i>Journal 1</i>. 1(3).	paper-title-number-3	http://academicpages.github.io/files/paper3.pdf

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("my_pubs.tsv", sep="\t", header=0)
publications
# Out:
#       pub_date                                              title  \
# 0   2018-09-07  Tuning Brønsted acid strength by altering site...
# 1   2019-03-21  Restructuring of MFI framework zeolite models ...
# 2   2019-07-05  Mechanism and Kinetics of Methylating C6 - C12...
# 3   2019-12-01  Mechanistic origins of the high-pressure inhib...
# 4   2020-06-19  Highly Selective Cross-Etherification of 5-Hyd...
# 5   2020-10-12  Rigid arrangements of ionic charge in zeolite ...
# 6   2020-11-10  Experimental and Theoretical Assessments of Al...
# 7   2021-09-16  Theoretical and Experimental Characterization ...
# 8   2021-08-01  Comparing alkene-mediated and formaldehyde-med...
# 9   2022-03-09  Quantifying Effects of Active Site Proximity o...
# 10  2022-10-07  Experimental and Theoretical Characterization ...
# 11  2022-08-09  Altering the Arrangement of Framework Al Atoms...
# 12  2023-03-20  Brønsted acid strength does not change for bul...
# 13  2024-03-01  Synthesizing different lta-cage zeolites with ...
# 14  2024-03-01  Automatically generating hypothetical molecule...
# 15  2024-03-01  Identifying descriptors for zeolite synthesis ...
# 16  2024-03-01  Graph convolutional neural networks for determ...
# 17  2024-03-01  Understanding the role of inorganic structure-...
#
#                                       venue  excerpt  \
# 0                             ACS catalysis      NaN
# 1       The Journal of Physical Chemistry C      NaN
# 2                             ACS catalysis      NaN
# 3                      Journal of catalysis      NaN
# 4                             ACS Catalysis      NaN
# 5   Angewandte Chemie International Edition      NaN
# 6                    Chemistry of Materials      NaN
# 7       The Journal of Physical Chemistry C      NaN
# 8                      Journal of catalysis      NaN
# 9                          ACS Materials Au      NaN
# 10                            ACS Catalysis      NaN
# 11                   Chemistry of Materials      NaN
# 12                            ACS Catalysis      NaN
# 13                           In preparation      NaN
# 14                           In preparation      NaN
# 15                           In preparation      NaN
# 16                           In preparation      NaN
# 17                           In preparation      NaN
#
#                                              citation           url_slug  \
# 0   Nystrom, S.; Hoffman, A.; Hibbitts, D. Tuning ...         paired_bas
# 1   Hoffman, A.; DeLuca, M.; Hibbitts, D. Restruct...      restructuring
# 2   DeLuca, M.; Kravchenko, P.; Hoffman, A.; Hibbi...  arene_methylation
# 3   Di Iorio, J. R.; Hoffman, A. J.; Nimlos, C. T....         inhibition
# 4   Allen, M. C.; Hoffman, A. J.; Liu, T.; Webber,...          hmf_ether
# 5   Hoffman, A. J.; Bates, J. S.; Di Iorio, J. R.;...      pair_methanol
# 6   Nimlos, C. T.; Hoffman, A. J.; Hur, Y. G.; Lee...       mfi_aluminum
# 7   Hoffman, A. J.; Asokan, C.; Gadinas, N.; Kravc...            rh_nano
# 8   Kilburn, L.; DeLuca, M.; Hoffman, A. J.; Patel...       formaldehyde
# 9   Marsden, G.; Kostetskyy, P.; Sekiya, R.-S.; Ho...          mkm_pairs
# 10  Hoffman, A. J.; Asokan, C.; Gadinas, N.; Schro...          rh_single
# 11  Bickel, E. E.; Hoffman, A. J.; Lee, S.; Snider...            mel_mfi
# 12  Balcom, H.; Hoffman, A. J.; Locht, H.; Hibbitt...       external_bas
# 13  Kwon, S.; Lee, H.; Hoffman, A. J.; Xie, M.; Gó...            lta_zeo
# 14  Xie, M.; Paris, C.; Hoffman, A. J.; Schwalbe-K...      hypotheticals
# 15  Hoffman, A. J.; Xie, M.; Gómez-Bombarelli, R. ...              sisso
# 16  Hoffman, A. J.; Paris, C.; Xie, M.; Moliner, M...      gcnn_aluminum
# 17  Hoffman, A. J.; Pan, E.; Kwon, S.; Xie, M.; Ro...       isda_binding
#
#                                             paper_url
# 0    http://pubs.acs.org/doi/10.1021/acscatal.8b02049
# 1    http://pubs.acs.org/doi/10.1021/acs.jpcc.8b12230
# 2    http://pubs.acs.org/doi/10.1021/acscatal.9b00650
# 3   https://linkinghub.elsevier.com/retrieve/pii/S...
# 4   https://pubs.acs.org/doi/10.1021/acscatal.0c01328
# 5   https://onlinelibrary.wiley.com/doi/10.1002/an...
# 6   https://pubs.acs.org/doi/10.1021/acs.chemmater...
# 7   https://pubs.acs.org/doi/10.1021/acs.jpcc.1c05160
# 8   https://linkinghub.elsevier.com/retrieve/pii/S...
# 9   https://pubs.acs.org/doi/10.1021/acsmaterialsa...
# 10  https://pubs.acs.org/doi/10.1021/acscatal.2c02813
# 11  https://pubs.acs.org/doi/10.1021/acs.chemmater...
# 12  https://pubs.acs.org/doi/10.1021/acscatal.3c00076
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        md += "\n" + html_escape(item.excerpt) + "\n"
    
    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# 2009-10-01-paper-title-number-1.md  2021-09-16-rh_nano.md
# 2010-10-01-paper-title-number-2.md  2022-03-09-mkm_pairs.md
# 2015-10-01-paper-title-number-3.md  2022-08-09-mel_mfi.md
# 2018-09-07-paired_bas.md	    2022-10-07-rh_single.md
# 2019-03-21-restructuring.md	    2023-03-20-external_bas.md
# 2019-07-05-arene_methylation.md     2024-03-01-gcnn_aluminum.md
# 2019-12-01-inhibition.md	    2024-03-01-hypotheticals.md
# 2020-06-19-hmf_ether.md		    2024-03-01-isda_binding.md
# 2020-10-12-pair_methanol.md	    2024-03-01-lta_zeo.md
# 2020-11-10-mfi_aluminum.md	    2024-03-01-sisso.md
# 2021-08-01-formaldehyde.md

# %%
# !cat ../_publications/2009-10-01-paper-title-number-1.md
# Out:
# ---
# title: "Paper Title Number 1"
# collection: publications
# permalink: /publication/2009-10-01-paper-title-number-1
# excerpt: 'This paper is about the number 1. The number 2 is left for future work.'
# date: 2009-10-01
# venue: 'Journal 1'
# paperurl: 'http://academicpages.github.io/files/paper1.pdf'
# citation: 'Your Name, You. (2009). &quot;Paper Title Number 1.&quot; <i>Journal 1</i>. 1(1).'
# ---
# This paper is about the number 1. The number 2 is left for future work.
#
# [Download paper here](http://academicpages.github.io/files/paper1.pdf)
#
# Recommended citation: Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).
